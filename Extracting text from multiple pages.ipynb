# %% [markdown]
# # Scraping multiple Pages
#
# Now, there may arise various instances where you may want to get data from multiple pages from the same website or multiple different URLs as well, and manually writing code for each webpage is a time-consuming and tedious task. Plus, it defines all basic principles of automation. Duh!
#
# To solve this exact problem, we will see two main techniques that will help us extract data from multiple webpages:
#
# The same website
# Different website URLs
# # Extracting title from page 4

# %%
import requests
from bs4 import BeautifulSoup as bs

URL = 'https://www.geeksforgeeks.org/page/2/'

req = requests.get(URL)
soup = bs(req.text, 'html.parser')

titles = soup.find_all('div',attrs = {'class','head'})

print(titles[3].text)
# Out:
# Flutter: Advantages & Disadvantages

# %% [markdown]
# # Extracting titles from pages 4-19

# %%
import requests
from bs4 import BeautifulSoup as bs

URL = 'https://www.geeksforgeeks.org/page/'

for page in range(2, 10):

	req = requests.get(URL + str(page) + '/')
	soup = bs(req.text, 'html.parser')

	titles = soup.find_all('div', attrs={'class', 'head'})

	for i in range(4, 19):
		if page > 1:
			print(f"{(i-3)+page*15}" + titles[i].text)
		else:
			print(f"{i-3}" + titles[i].text)
# Out:
# 31How to become a Full Stack Developer? Complete Roadmap 2023
# 32Top UI/UX Trends of 2023
# 33Web Browser & it's Working
# 34How to Answer “Tell Me About Yourself” in an Interview?
# 35Top 5 Reasons Why Your Resume gets Rejected
# 365 DSA Projects for your Resume
# 37Difference between Substitution Effect and Income Effect
# 38Retirement of a Partner in case of Reconstitution of a Partnership Firm
# 39Two nodes in a Linked list whose product is equal to the target value
# 40Introduction to Rolling Hash – Data Structures and Algorithms
# 41IFRS (International Financial Reporting Standards) and GAAP (Generally Accepted Accounting Principles)
# 42Restricted movement to reach the given point on a board
# 43How to create Infinite Scrolling using onScroll Event in JavaScript ?
# 44Consecutive group formation in Array of size N
# 45How to align a <div> element to the middle of a page using CSS ?
# 46How to become a Full Stack Developer? Complete Roadmap 2023
# 47Top UI/UX Trends of 2023
# 48Web Browser & it's Working
# 49How to Answer “Tell Me About Yourself” in an Interview?
# 50Top 5 Reasons Why Your Resume gets Rejected
# 515 DSA Projects for your Resume
# 52Recommend a way to optimize a certain webpage for prints using CSS
# 53Difference between React.cloneElement and this.props.children
# 54How to set height equal to dynamic width (CSS fluid layout) ?
# 55Server Side Rendering vs Client Side Rendering vs Server Side Generation
# 56XMLHttpRequest.responseType Property
# 57PHP fdiv() Function
# 58PHP mb_split() Function
# 59PHP log1p() Function
# 60PHP mb_strtolower() Function
# 61How to become a Full Stack Developer? Complete Roadmap 2023
# 62Top UI/UX Trends of 2023
# 63Web Browser & it's Working
# 64How to Answer “Tell Me About Yourself” in an Interview?
# 65Top 5 Reasons Why Your Resume gets Rejected
# 665 DSA Projects for your Resume
# 67What is the Atomic Mass of Chlorine?
# 68Fertilizations And Implantation
# 69How to Implement OTP View in Android?
# 70Difference Between Spermatogenesis And Oogenesis
# 71Medical Termination of Pregnancy (MTP)
# 72Difference Between Cereals And Pulses
# 73Difference Between Right and Left Lung
# 74Difference Between Cytosol And Cytoplasm
# 75Fossils
# 76How to become a Full Stack Developer? Complete Roadmap 2023
# 77Top UI/UX Trends of 2023
# 78Web Browser & it's Working
# 79How to Answer “Tell Me About Yourself” in an Interview?
# 80Top 5 Reasons Why Your Resume gets Rejected
# 815 DSA Projects for your Resume
# 82Importance of Variation
# 835 Color Theorem in Graph Theory
# 84How To Find Minimal Set?
# 85Cyclic Scheduler in Real Time System
# 86Security of Cyber-Physical System
# 87Difference Between High Performance Computing and High Throughput Computing
# 88Advantages and Disadvantages of an ER-Model
# 89Sumo Logic vs Splunk
# 90Kibana vs Splunk
# 91How to become a Full Stack Developer? Complete Roadmap 2023
# 92Top UI/UX Trends of 2023
# 93Web Browser & it's Working
# 94How to Answer “Tell Me About Yourself” in an Interview?
# 95Top 5 Reasons Why Your Resume gets Rejected
# 965 DSA Projects for your Resume
# 97Java Program to Find the Arboricity of a Graph
# 98Deployment of React Application using GitHub Pages
# 99Custom Toast in Android Using PoiziToast Library
# 100Flutter – Load JSON Assets
# 101How to Implement Country Code Picker in Android?
# 102How to Display Percentage on a ProgressBar in Android?
# 103How to Push Anything to GitHub using Git Bash?
# 104Hibernate – Cache Eviction with Example
# 105Flutter – Difference Between ListView and List
# 106How to become a Full Stack Developer? Complete Roadmap 2023
# 107Top UI/UX Trends of 2023
# 108Web Browser & it's Working
# 109How to Answer “Tell Me About Yourself” in an Interview?
# 110Top 5 Reasons Why Your Resume gets Rejected
# 1115 DSA Projects for your Resume
# 112How to Check Navigation Drawer Menu Items in Android?
# 113How to Add Images in RecyclerView using Firebase?
# 114How to Get the Height of a Widget in Flutter?
# 115Flutter – Advanced Drawer
# 116How to Add Line ProgressBar with CardView using Buttons in Android?
# 117Puzzle – Bank Cashier Mistake
# 118Puzzle – Secret Word
# 119Count number of Subsequences in Array in which X and Y are min and max elements
# 120Describe the Work of a Farmer with 1 Hectare of Land
# 121How to become a Full Stack Developer? Complete Roadmap 2023
# 122Top UI/UX Trends of 2023
# 123Web Browser & it's Working
# 124How to Answer “Tell Me About Yourself” in an Interview?
# 125Top 5 Reasons Why Your Resume gets Rejected
# 1265 DSA Projects for your Resume
# 127Visualising the Nation- CBSE Class 10 History
# 128What were the subjects on which books were written in the past?
# 129Megaliths
# 130How numbers are stored in JavaScript ?
# 131Dual Government of Robert Clive
# 132Introduction to Degenerate Binary Tree
# 133How to change href attribute of a hyperlink using jQuery ?
# 134Application of Remote Sensing
# 135TCP with Buffering Capability and Sequencing Information
# 136How to become a Full Stack Developer? Complete Roadmap 2023
# 137Top UI/UX Trends of 2023
# 138Web Browser & it's Working
# 139How to Answer “Tell Me About Yourself” in an Interview?
# 140Top 5 Reasons Why Your Resume gets Rejected
# 1415 DSA Projects for your Resume
# 142Square Meter (Meter Squared)
# 143Photocell and Probability Interpretation to Matter Waves
# 144Preparation of Alcohols
# 145Structural Representations of Organic Compounds
# 146Rectangular Matrix
# 147Hermitian Matrix
# 148Jira vs ServiceNow
# 149Row Matrix
# 150Similar Matrix
